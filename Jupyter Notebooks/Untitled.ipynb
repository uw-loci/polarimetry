# %%
import matplotlib.pyplot as plt

# %%
x = [0, 2.5, 3.6]
y = [3, 1.84, 1.85]

plt.scatter(x,y)
plt.xaxes([0, 4])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4bee4c7f4a00> in <module>()
#       3
#       4 plt.scatter(x,y)
# ----> 5 plt.xaxes([0, 4])
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xaxes'
